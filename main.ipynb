# %%
import pandas as pd
import numpy as np
from repo_funciones import *

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
data = pd.read_csv('../Sharknado/attacks_messy.csv', encoding='utf-8',encoding_errors="ignore" )

# %%
dim_original = data.shape #Para luego ir comparando
dim_original
# Out:
# (25723, 24)

# %%
data.head() #con tail() vemos que al final hay muchos valores nulos
# Out:
#   Case Number         Date    Year        Type    Country             Area
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California  \
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity            Name Sex   Age
# 0     Oceanside, San Diego County     Paddling     Julie Wolfe    F   57  \
# 1  St. Simon Island, Glynn County     Standing  AdysonMcNeely     F   11
# 2                    Habush, Oahu      Surfing     John Denges    M   48
# 3              Arrawarra Headland      Surfing            male    M  NaN
# 4                        La Ticla  Free diving  Gustavo Ramos     M  NaN
#
#                                               Injury Fatal (Y/N)
# ...

# %%
data.info() #guay pero falta ver donnde hay mas trabajo. Un conteo de valores nulos por column o algo asi
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
# ...

# %%
data= data.drop_duplicates()

# %%
data.duplicated().unique()
# Out:
# array([False])

# %%
data.shape
# Out:
# (6312, 24)

# %%
data=data.drop(nanrows(data)[nanrows(data)> 19])

# %%
data.shape
# Out:
# (6309, 24)

# %%
data = data.drop(data[nanrows(data) >= 15])
# Out:
# C:\Users\anton\AppData\Local\Temp\ipykernel_7896\955605597.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data = data.drop(data[nanrows(data) >= 15].index)

# %%
data.shape
# Out:
# (6299, 24)

# %%
data.tail()
# Out:
#      Case Number         Date  Year        Type             Country
# 6297     ND.0005  Before 1903   0.0  Unprovoked           AUSTRALIA  \
# 6298     ND.0004  Before 1903   0.0  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905   0.0  Unprovoked                 USA
# 6300     ND.0002    1883-1889   0.0  Unprovoked              PANAMA
# 6301     ND.0001    1845-1853   0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity
# 6297  Western Australia                          Roebuck Bay        Diving  \
# 6298  Western Australia                                  NaN  Pearl diving
# 6299     North Carolina                       Ocracoke Inlet      Swimming
# 6300                NaN                   Panama Bay 8N, 79W           NaN
# 6301   Eastern Province  Below the English fort, Trincomalee      Swimming
#
#                        Name Sex   Age
# 6297                   male    M  NaN  \
# ...

# %%
data["Unnamed: 22"].unique()
# Out:
# array([nan, 'stopped here'], dtype=object)

# %%
data["Unnamed: 23"].unique()
# Out:
# array([nan, 'Teramo', 'change filename'], dtype=object)

# %%
#columnas 22 y 23 tienen demasiados valores nulos para ser representatrivas. las rellenamos
data[["Unnamed: 23", "Unnamed: 22"]] = data[["Unnamed: 23", "Unnamed: 22"]].fillna(0)

# %%
data["Time"].unique()
# Out:
# array(['18h00', '14h00  -15h00', '07h45', nan, 'Late afternoon', '17h00',
#        '14h00', 'Morning', '15h00', '08h15', '11h00', '10h30', '10h40',
#        '16h50', '07h00', '09h30', '08h00', '17h35', '15h30', '07h30',
#        '19h00, Dusk', 'Night', '16h00', '15h01', '12h00', '13h45',
#        '23h30', '09h00', 'Afternoon', '14h30', '18h30', '12h30', '16h30',
#        '18h45', '06h00', '10h00', '10h44', '13h19', 'Midday', '13h30',
#        '10h45', '11h20', '11h45', '19h30', '08h30', '15h45',
#        'Shortly before 12h00', '17h34', '17h10', '11h15', '08h50',
#        '17h45', '13h00', '10h20', '13h20', '02h00', '09h50', '11h30',
#        '17h30', '9h00', '10h43', 'After noon', '15h15', '15h40', '19h05',
#        '1300', '14h30 / 15h30', '22h00', '16h20', '14h34', '15h25',
#        '14h55', '17h46', 'Morning ', '15h49', '19h00', 'Midnight',
#        '09h30 / 10h00', '10h15', '18h15', '04h00', '14h50', '13h50',
#        '19h20', '10h25', '10h45-11h15', '16h45', '15h52', '06h15',
# ...

# %%
data["Time"]=data["Time"].fillna("unknown")

# %%
data["Time"] = data["Time"].str.replace('h',':')

# %%
duplicated_data = data[data.duplicated()]
duplicated_data
# Out:
# Empty DataFrame
# Columns: [Case Number, Date, Year, Type, Country, Area, Location, Activity, Name, Sex , Age, Injury, Fatal (Y/N), Time, Species , Investigator or Source, pdf, href formula, href, Case Number.1, Case Number.2, original order, Unnamed: 22, Unnamed: 23]
# Index: []

# %%
data.shape, dim_original
# Out:
# ((6299, 24), (25723, 24))

# %%
nanrows(data)
# Out:
# 6165    7
# 6130    7
# 5036    7
# 6122    7
# 6108    7
# 6080    7
# 4976    7
# 3378    6
# 6171    6
# 5846    6
# 5812    6
# 1848    6
# 6081    6
# 5729    6
# 6092    6
# 5029    6
# 3938    6
# 5246    6
# 5693    6
# 6133    6
# 4018    6
# 6125    6
# 5850    6
# 6158    6
# 4680    6
# 5965    6
# 5895    6
# 6044    6
# 5356    6
# 1366    6
# 2196    6
# 6199    6
# 5880    6
# 3033    6
# 1569    6
# 5621    5
# 6195    5
# 2160    5
# 6145    5
# 6141    5
# 4517    5
# 4445    5
# 5586    5
# 4454    5
# 4493    5
# 4196    5
# 5587    5
# 5614    5
# 4187    5
# 154     5
# 2409    5
# 4252    5
# 6174    5
# 4373    5
# 2208    5
# 3426    5
# 2279    5
# 6167    5
# 3454    5
# 5433    5
# 3425    5
# 1088    5
# 3157    5
# 6192    5
# 3572    5
# 4255    5
# 4338    5
# 6157    5
# 5712    5
# 4907    5
# 5888    5
# 5854    5
# 3774    5
# 3508    5
# 5874    5
# 3746    5
# 525     5
# 5885    5
# 6056    5
# 3516    5
# 226     5
# 6053    5
# 3712    5
# ...

# %%
data.shape, dim_original
# Out:
# ((6299, 24), (25723, 24))

# %%
data.tail()
# Out:
#      Case Number         Date  Year        Type             Country
# 6297     ND.0005  Before 1903   0.0  Unprovoked           AUSTRALIA  \
# 6298     ND.0004  Before 1903   0.0  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905   0.0  Unprovoked                 USA
# 6300     ND.0002    1883-1889   0.0  Unprovoked              PANAMA
# 6301     ND.0001    1845-1853   0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity
# 6297  Western Australia                          Roebuck Bay        Diving  \
# 6298  Western Australia                                  NaN  Pearl diving
# 6299     North Carolina                       Ocracoke Inlet      Swimming
# 6300                NaN                   Panama Bay 8N, 79W           NaN
# 6301   Eastern Province  Below the English fort, Trincomalee      Swimming
#
#                        Name Sex   Age
# 6297                   male    M  NaN  \
# ...

# %%
#data = data.drop([6307, 6308, 6309, 8702, 25722]) #que hiciste aqui?
#data.iloc[[6307, 6308, 6309, 8702, 25722]]
data = data.reset_index(drop=True)

# %%
data= data.drop(data["Case Number"][data["Case Number"]==0])

# %%
data.shape, dim_original
# Out:
# ((6299, 24), (25723, 24))

# %%
data.shape, dim_original
# Out:
# ((6299, 24), (25723, 24))

# %%
data["Case Number"][data["Case Number"].isna()]
# Out:
# 5485    NaN
# Name: Case Number, dtype: object

# %%
data.loc[data["Case Number"].isna()]
# Out:
#      Case Number                  Date    Year      Type Country     Area
# 5485         NaN  Reported 06-Sep-1905  1905.0  Provoked     USA  Florida  \
#
#                           Location Activity         Name Sex   Age
# 5485  Fort Pierce, St Lucie County  Fishing  David Curry    M  NaN  \
#
#                                                  Injury Fatal (Y/N)     Time
# 5485  Lacerations to leg from hooked shark PROVOKED ...           N  unknown  \
#
#      Species           Investigator or Source                     pdf
# 5485      NaN  Muncie Evening Press, 8/6/1913  1905.09.06.R-Curry.pdf  \
#
#                                            href formula
# 5485  http://sharkattackfile.net/spreadsheets/pdf_di...  \
#
#                                                    href Case Number.1
# 5485  http://sharkattackfile.net/spreadsheets/pdf_di...  1905.09.06.R  \
#
#      Case Number.2  original order Unnamed: 22 Unnamed: 23
# ...

# %%
data["Case Number"].fillna("1905.09.06.R", inplace=True)

# %%
data.loc[data["Year"].isna()]
# Out:
#        Case Number                  Date  Year        Type    Country
# 184   2017.01.08.R  Reported 08-Jan-2017   NaN     Invalid  AUSTRALIA  \
# 6076  1836.08.19.R  Reported 19-Aug-1836   NaN  Unprovoked    ENGLAND
#
#             Area    Location      Activity          Name Sex   Age
# 184   Queensland         NaN  Spearfishing  Kerry Daniel    M   35  \
# 6076  Cumberland  Whitehaven      Swimming         a boy    M  NaN
#
#                                       Injury Fatal (Y/N)     Time    Species
# 184   No attack, shark made a threat display         NaN  unknown  Bull shark  \
# 6076                                   FATAL           Y  unknown         NaN
#
#       Investigator or Source                           pdf
# 184   Liquid Vision 1/8/2017  2017.01.08.R-KerryDaniel.pdf  \
# 6076          C. Moore, GSAF   1835.08.19.R-Whitehaven.pdf
#
#                                            href formula
# 184   http://sharkattackfile.net/spreadsheets/pdf_di...  \
# ...

# %%
#data["Year"].fillna(data["Case Number"], inplace=True) #elc ase number viene elk año, luego habrá que limpiarlo...

# %%
data["Type"].fillna("Invalid", inplace=True)

# %%
data["href formula"].fillna(data["href"], inplace=True)

# %%
data.loc[data["Investigator or Source"].isna()].head()
# Out:
#        Case Number         Date    Year        Type    Country
# 116   2017.07.14.a  14-Jul-2017  2017.0  Unprovoked  AUSTRALIA  \
# 287   2016.04.07.b  07-Apr-2016  2016.0  Unprovoked        USA
# 379     2015.07.27  27-Jul-2015  2015.0     Invalid  AUSTRALIA
# 628   2013.08.31.b  31-Aug-2013  2013.0  Unprovoked    BAHAMAS
# 1127    2009.04.28  28-Apr-2009  2009.0  Unprovoked        USA
#
#                    Area                          Location      Activity
# 116   Western Australia                     Floreat Beach       Surfing  \
# 287             Florida       Florida Keys, Monroe County       Fishing
# 379            Victoria                  Tyrendarra Beach       Surfing
# 628                 NaN                    Freetown Beach  Spearfishing
# 1127            Florida  St. Augustine, St. John's County           NaN
#
#                  Name Sex   Age                                      Injury
# ...

# %%
data.tail()
# Out:
#      Case Number         Date  Year        Type             Country
# 6294     ND.0005  Before 1903   0.0  Unprovoked           AUSTRALIA  \
# 6295     ND.0004  Before 1903   0.0  Unprovoked           AUSTRALIA
# 6296     ND.0003    1900-1905   0.0  Unprovoked                 USA
# 6297     ND.0002    1883-1889   0.0  Unprovoked              PANAMA
# 6298     ND.0001    1845-1853   0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity
# 6294  Western Australia                          Roebuck Bay        Diving  \
# 6295  Western Australia                                  NaN  Pearl diving
# 6296     North Carolina                       Ocracoke Inlet      Swimming
# 6297                NaN                   Panama Bay 8N, 79W           NaN
# 6298   Eastern Province  Below the English fort, Trincomalee      Swimming
#
#                        Name Sex   Age
# 6294                   male    M  NaN  \
# ...

# %%
data["Name"].fillna("NA" , inplace=True) #La variable nombre en verdad no creo sea indicativa de nada para analisis. Será que las lucias son mas propensas a ataques? pos wel never know

# %%
#data.loc[data[['Country', 'Area', 'Location']].isna().all(axis=1), ['Country', 'Area', 'Location']] = "unknown" #si las tres columnas no tienen valor a la vez, remplazar con unknown. Para las que al menos una de ellas tengan valores podemos hacer algo maybe

# %%
def unique_cols(x):
    unique_cols = x.nunique()
    return unique_cols.sort_values(ascending=False)

# %%
unique_cols(data) #algunos no tiene sentido que tengan tantos valores unicos, como sexo, fatal...
# Out:
# original order            6298
# pdf                       6288
# href formula              6288
# Case Number               6283
# Case Number.2             6283
# Case Number.1             6282
# href                      6282
# Date                      5430
# Name                      5229
# Investigator or Source    4968
# Location                  4100
# Injury                    3734
# Species                   1547
# Activity                  1531
# Area                       824
# Time                       365
# Year                       249
# Country                    211
# Age                        155
# Fatal (Y/N)                  8
# Type                         8
# Sex                          6
# Unnamed: 23                  3
# Unnamed: 22                  2
# dtype: int64

# %%
data["Sex "].unique()
# Out:
# array(['F', 'M', nan, 'M ', 'lli', 'N', '.'], dtype=object)

# %%
print(data.loc[5435, 'Injury'])
# Out:
# FATAL

# %%
#data[data['Sex '] == 'M ']= "M" #CUIDADO AQUI ESTABAS SOBRESCRIBIENDO COLUMNAS ENTERAS TIEN$ES QUE PONER EL FILTRO DE COLUMNA PRIMEROOO
#abajo está bien

# %%
#data["Sex "][data['Sex '] == 'lli']="M" #tiene nombre de hombre
#aquí ya estaría bien pero nos arroja mensaje de que estamos sobrescribiendo una copia of a slice cambiams sytanxis

# %%
data.loc[data["Sex "] == "lli", "Sex "]="M" 

"""SYNTAX:

data.loc, mi fav que Carlos no le gusta -> method para seleccionar filas/columnas usando valores de indices
 -> la syntaxis es data.loc[fila, columna]
 -> en este caso fila se selecciona con "data["Sex "] == "lli"'"saca mascara booleana  donde se cumpla la condición
 -> y la columna sex 
  -> selecciona las filas donde se cumple la condicion pero solo selecciona la columna especificada
-> se termina sobrescribiendo con el valor que queremos asignar

"""
# Out:
# 'SYNTAX:\n\ndata.loc, mi fav que Carlos no le gusta -> method para seleccionar filas/columnas usando valores de indices\n -> la syntaxis es data.loc[fila, columna]\n -> en este caso fila se selecciona con "data["Sex "] == "lli"\'"saca mascara booleana  donde se cumpla la condición\n -> y la columna sex \n  -> selecciona las filas donde se cumple la condicion pero solo selecciona la columna especificada\n-> se termina sobrescribiendo con el valor que queremos asignar\n\n'

# %%
#data[data['Sex '] == 'M ']= "M"
data.loc[data["Sex "]== "M ", "Sex "]="M"

# %%
#data["Sex "][data['Sex '] == 'N']= "M" #nombres de hombres
data.loc[data["Sex "]=="N", "Sex "]="M"

# %%
data["Sex "].unique()
# Out:
# array(['F', 'M', nan, '.'], dtype=object)

# %%
#data[data['Sex '] == "."]="unknown" #para tener un . mejor un unknwown, son varias personas enb injury decen asi que unknown
data.loc[data["Sex "]==".", "Sex "]="unknown"

# %%
data.loc[data["Sex "].isna() & data["Name"].isna(), "Sex "] = "unknown"

# %%
#data["Sex "].fillna("unknown", inplace=True) #no hay indicios de sexo para estos valores nulos.

# %%
data["Fatal (Y/N)"].unique()
# Out:
# array(['N', 'Y', nan, 'M', 'UNKNOWN', '2017', ' N', 'N ', 'y'],
#       dtype=object)

# %%
data[data["Fatal (Y/N)"] == 'M']
# Out:
#       Case Number         Date    Year      Type           Country      Area
# 282  2016.04.18.b  18-Apr-2016  2016.0  Provoked  FRENCH POLYNESIA  Tuamotos  \
#
#          Location      Activity         Name Sex  Age
# 282  Makemo Atoll  Spearfishing  Hoata Iotua    M  22  \
#
#                                                 Injury Fatal (Y/N)     Time
# 282  Laceration to knee by speared shark PROVOKED I...           M  Morning  \
#
#                  Species  Investigator or Source                     pdf
# 282  Grey reef shark, 2 m   TNTV News, 4/19/2016  2016.04.18.b-Iotua.pdf  \
#
#                                           href formula
# 282  http://sharkattackfile.net/spreadsheets/pdf_di...  \
#
#                                                   href Case Number.1
# 282  http://sharkattackfile.net/spreadsheets/pdf_di...  2016.04.18.b  \
#
#     Case Number.2  original order Unnamed: 22 Unnamed: 23
# 282  2016.04.18.b          6018.0           0           0

# %%
data = data.reset_index(drop=True)

# %%
# data = data.drop([561,1585,4936,6129,1622]) #NOPPPPPP aqui estaban los valores mal porque sobreescribiste filas enteras coquin

# %%
data.loc[data["Fatal (Y/N)"] == 'M', "Fatal (Y/N)"] = "N" #injury no parece indicar que murió, ponemos no

# %%
print(data.loc[283, 'Injury']) #pasra visualizar todo el texto que viene en injury
# Out:
# Severe lacerations to right forearm, hand and calf from speared shark PROVOKED INCIDENT

# %%
#data["Fatal (Y/N)"][data["Fatal (Y/N)"] == '2017']="N"    #cambiamos por mensaje de error
#A value is trying to be set on a copy of a slice from a DataFrame
data.loc[data["Fatal (Y/N)"] == "2017", "Fatal (Y/N)"]="N"

# %%
#data[data["Fatal (Y/N)"] == 'y']="Y"
data.loc[data["Fatal (Y/N)"]=="y", "Fatal (Y/N)"]="Y"

# %%
#data[data["Fatal (Y/N)"] == 'N ']="N"
data.loc[data["Fatal (Y/N)"]=="N ","Fatal (Y/N)" ]="N"

# %%
#data[data["Fatal (Y/N)"] == ' N']="N"
data.loc[data["Fatal (Y/N)"]==" N", "Fatal (Y/N)"]="N"

# %%
#data[data["Fatal (Y/N)"]=="UNKNOWN"]="unknown"
data.loc[data["Fatal (Y/N)"]=="UNKNOWN", "Fatal (Y/N)"]="unknown"

# %%
data.loc[(data["Fatal (Y/N)"].isna()) & (data["Injury"] == "FATAL"), "Fatal (Y/N)"] = "Y"

# %%
data.duplicated().unique()
# Out:
# array([False])

# %%
data[data["Case Number"]== 'Y']
# Out:
# Empty DataFrame
# Columns: [Case Number, Date, Year, Type, Country, Area, Location, Activity, Name, Sex , Age, Injury, Fatal (Y/N), Time, Species , Investigator or Source, pdf, href formula, href, Case Number.1, Case Number.2, original order, Unnamed: 22, Unnamed: 23]
# Index: []

# %%
data.loc[data["Fatal (Y/N)"].isna(), "Fatal (Y/N)"]="unknown"

# %%
data.loc[data["Year"].isna()]
# Out:
#        Case Number                  Date  Year        Type    Country
# 184   2017.01.08.R  Reported 08-Jan-2017   NaN     Invalid  AUSTRALIA  \
# 6076  1836.08.19.R  Reported 19-Aug-1836   NaN  Unprovoked    ENGLAND
#
#             Area    Location      Activity          Name Sex   Age
# 184   Queensland         NaN  Spearfishing  Kerry Daniel    M   35  \
# 6076  Cumberland  Whitehaven      Swimming         a boy    M  NaN
#
#                                       Injury Fatal (Y/N)     Time    Species
# 184   No attack, shark made a threat display     unknown  unknown  Bull shark  \
# 6076                                   FATAL           Y  unknown         NaN
#
#       Investigator or Source                           pdf
# 184   Liquid Vision 1/8/2017  2017.01.08.R-KerryDaniel.pdf  \
# 6076          C. Moore, GSAF   1835.08.19.R-Whitehaven.pdf
#
#                                            href formula
# 184   http://sharkattackfile.net/spreadsheets/pdf_di...  \
# ...

# %%
"""def get_unique_dtypes(df, col):
    unique_dtypes = df[col].apply(lambda x: type(x)).unique()
    return unique_dtypes"""
# Out:
# 'def get_unique_dtypes(df, col):\n    unique_dtypes = df[col].apply(lambda x: type(x)).unique()\n    return unique_dtypes'

# %%
get_unique_dtypes(data, "Year")
# Out:
# array([<class 'float'>], dtype=object)

# %%
data.loc[data["Year"]=="NaN"]
# Out:
# Empty DataFrame
# Columns: [Case Number, Date, Year, Type, Country, Area, Location, Activity, Name, Sex , Age, Injury, Fatal (Y/N), Time, Species , Investigator or Source, pdf, href formula, href, Case Number.1, Case Number.2, original order, Unnamed: 22, Unnamed: 23]
# Index: []

# %%
nancols(data)
# Out:
# Species                   2838
# Age                       2830
# Sex                        565
# Activity                   544
# Location                   540
# Area                       455
# Country                     50
# Injury                      28
# Investigator or Source      17
# Year                         2
# Case Number                  0
# Case Number.1                0
# original order               0
# Case Number.2                0
# href formula                 0
# Unnamed: 22                  0
# href                         0
# Fatal (Y/N)                  0
# pdf                          0
# Time                         0
# Date                         0
# Name                         0
# Type                         0
# Unnamed: 23                  0
# dtype: int64

# %%
#data[data["Year"].apply(lambda x: isinstance(x, str))]#["Year"]

# %%
#data["Year"]= pd.to_datetime(data["Year"]) ta mal

# %%
data.loc[data["Year"].isna()]
# Out:
#        Case Number                  Date  Year        Type    Country
# 184   2017.01.08.R  Reported 08-Jan-2017   NaN     Invalid  AUSTRALIA  \
# 6076  1836.08.19.R  Reported 19-Aug-1836   NaN  Unprovoked    ENGLAND
#
#             Area    Location      Activity          Name Sex   Age
# 184   Queensland         NaN  Spearfishing  Kerry Daniel    M   35  \
# 6076  Cumberland  Whitehaven      Swimming         a boy    M  NaN
#
#                                       Injury Fatal (Y/N)     Time    Species
# 184   No attack, shark made a threat display     unknown  unknown  Bull shark  \
# 6076                                   FATAL           Y  unknown         NaN
#
#       Investigator or Source                           pdf
# 184   Liquid Vision 1/8/2017  2017.01.08.R-KerryDaniel.pdf  \
# 6076          C. Moore, GSAF   1835.08.19.R-Whitehaven.pdf
#
#                                            href formula
# 184   http://sharkattackfile.net/spreadsheets/pdf_di...  \
# ...

# %%
#data.iloc[184]["Year"]=2017
data.loc[184, "Year"]="2017"

# %%
data.loc[6076, "Year"]=1836

# %%
data.iloc[[184,6076]]
# Out:
#        Case Number                  Date  Year        Type    Country
# 184   2017.01.08.R  Reported 08-Jan-2017  2017     Invalid  AUSTRALIA  \
# 6076  1836.08.19.R  Reported 19-Aug-1836  1836  Unprovoked    ENGLAND
#
#             Area    Location      Activity          Name Sex   Age
# 184   Queensland         NaN  Spearfishing  Kerry Daniel    M   35  \
# 6076  Cumberland  Whitehaven      Swimming         a boy    M  NaN
#
#                                       Injury Fatal (Y/N)     Time    Species
# 184   No attack, shark made a threat display     unknown  unknown  Bull shark  \
# 6076                                   FATAL           Y  unknown         NaN
#
#       Investigator or Source                           pdf
# 184   Liquid Vision 1/8/2017  2017.01.08.R-KerryDaniel.pdf  \
# 6076          C. Moore, GSAF   1835.08.19.R-Whitehaven.pdf
#
#                                            href formula
# 184   http://sharkattackfile.net/spreadsheets/pdf_di...  \
# ...

# %%
data["Year"] = data["Year"].astype(int)

# %%
data.columns = data.columns.str.strip().str.capitalize().str.title().str.replace(':','').str.replace(' ','_').str.replace('.','_')

# %%
data.columns
# Out:
# Index(['Case_Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex', 'Age', 'Injury', 'Fatal_(Y/N)', 'Time',
#        'Species', 'Investigator_Or_Source', 'Pdf', 'Href_Formula', 'Href',
#        'Case_Number_1', 'Case_Number_2', 'Original_Order', 'Unnamed_22',
#        'Unnamed_23'],
#       dtype='object')

# %%
"""data.fillna({'type':'unknown', 'location' :  'unknown','name':'unknown', 'sex':'unknown','species':'unknown', 'injury':'not registered', 'fatal_(y/n)':'N/A',
                'investigator_or_source':'unknown', 'pdf':'not applies','href_formula': 'not applies',
                'href': 'not applies', 'unnamed_22': 0, 'unnamed_23': 0}, inplace = True)"""
# Out:
# "data.fillna({'type':'unknown', 'location' :  'unknown','name':'unknown', 'sex':'unknown','species':'unknown', 'injury':'not registered', 'fatal_(y/n)':'N/A',\n                'investigator_or_source':'unknown', 'pdf':'not applies','href_formula': 'not applies',\n                'href': 'not applies', 'unnamed_22': 0, 'unnamed_23': 0}, inplace = True)"

# %%
data["Investigator_Or_Source"]=data["Investigator_Or_Source"].fillna("unknown")

# %%
data["Time"] = data["Time"].str.rstrip()
data["Time"] = data["Time"].str.lstrip()

# %%
#convención de tiempo
#Morning: 6am a 12
#afternoon: 12 a 7
#night: 8 a 5am
#Asumimos que todos ingresaron la hora en formato 24h
data.loc[data["Time"]=="14:00  -15:00", "Time"]="14:30"
data.loc[data["Time"]=="Late afternoon", "Time"]="18:00"
data.loc[data["Time"]=="Morning", "Time"]="9:00"
data.loc[data["Time"]=="19:00, Dusk", "Time"]="19:00"
data.loc[data["Time"]=="Nig:t", "Time"]="21:00"
data.loc[data["Time"]=="Afternoon", "Time"]="17:00"
data.loc[data["Time"]=="Midday", "Time"]="13:00"
data.loc[data["Time"]=="S:ortly before 12:00", "Time"]="11:30"
data.loc[data["Time"]=="After noon", "Time"]="13:00"
data.loc[data["Time"]=="14:30 / 15:30", "Time"]="15:00"
data.loc[data["Time"]=="Midnig:t", "Time"]="24:00"
data.loc[data["Time"]=="09:30 / 10:00", "Time"]="09:40"
data.loc[data["Time"]=="10:45-11:15", "Time"]="11:00"
data.loc[data["Time"]=="Evening", "Time"]="20:00"
data.loc[data["Time"]=="Sometime between 06:00 & 08:oo", "Time"]="07:00"
data.loc[data["Time"]=="Early afternoon", "Time"]="14:00"
data.loc[data["Time"]=="18:15-18:30", "Time"]="18:20"
data.loc[data["Time"]=="09:00 - 09:30", "Time"]="09:15"
data.loc[data["Time"]=="0830", "Time"]="08:30"
data.loc[data["Time"]=="Just before noon", "Time"]="11:30"
data.loc[data["Time"]=="1600", "Time"]="16:00"
data.loc[data["Time"]=="Early morning", "Time"]="09:00"
data.loc[data["Time"]=="Dawn", "Time"]="07:00"
data.loc[data["Time"]=="AM", "Time"]="07:00"
data.loc[data["Time"]=="A.M", "Time"]="07:00"
data.loc[data["Time"]=="Dusk", "Time"]="20:00"
data.loc[data["Time"]=="Lunc:time", "Time"]="13:00"
data.loc[data["Time"]=="15j45", "Time"]="15:45"
data.loc[data["Time"]=="0500", "Time"]="05:00"
data.loc[data["Time"]=="Before 07:00", "Time"]="06:00"
data.loc[data["Time"]=="10:00 -- 11:00", "Time"]="10:30"
data.loc[data["Time"]=='"Just before 11:00"', "Time"]="10:30"
data.loc[data["Time"]=="Sunset", "Time"]="19:30"
data.loc[data["Time"]=="Just before sundown", "Time"]="19:30"
data.loc[data["Time"]=="Between 05:00 and 08:00", "Time"]="06:30"
data.loc[data["Time"]=="17:00 or 17:40", "Time"]="17:20"
data.loc[data["Time"]==">08:00", "Time"]="08:20"
data.loc[data["Time"]=="--", "Time"]="unknown"
data.loc[data["Time"]=="Just after 12:00", "Time"]="12:30"
data.loc[data["Time"]=="Early Morning", "Time"]="08:30"
data.loc[data["Time"]=="S:ortly after midnig:t", "Time"]="24:30"
data.loc[data["Time"]=="09:00 -10:00", "Time"]="09:30"
data.loc[data["Time"]=="20:45 (Sunset)", "Time"]="20:45"
data.loc[data["Time"]=="Late morning", "Time"]="11:00"
data.loc[data["Time"]=="P.M.", "Time"]="14:00"
data.loc[data["Time"]=="S:ortly before 13:00", "Time"]="12:00"
data.loc[data["Time"]=="8:04 pm", "Time"]="08:00"
data.loc[data["Time"]=="Possibly same incident as 2000.08.21", "Time"]="unknown"
data.loc[data["Time"]=="After Dusk", "Time"]="09:00"
data.loc[data["Time"]=="Noon", "Time"]="12:00"
data.loc[data["Time"]=="2 :ours after Opperman", "Time"]="unknown"
data.loc[data["Time"]=="Mid afternoon", "Time"]="14:00"
data.loc[data["Time"]=="Mid morning", "Time"]="11:00"
data.loc[data["Time"]=="11:00 / 11:30", "Time"]="11:00"
data.loc[data["Time"]=='"Nig:t"', "Time"]="21:00"
data.loc[data["Time"]=='18:30?', "Time"]="18:30"
data.loc[data["Time"]=='30 minutes after 1992.07.08.a', "Time"]="unknown"
data.loc[data["Time"]==">06:45", "Time"]="06:45"
data.loc[data["Time"]=="Between 06:00 & 07:20", "Time"]="06:45"
data.loc[data["Time"]=="<07:30", "Time"]="06:45"
data.loc[data["Time"]=="17:00 Sunset", "Time"]="17:00"
data.loc[data["Time"]=="Nig:tfal", "Time"]="20:00"
data.loc[data["Time"]=="X", "Time"]="unknown"
data.loc[data["Time"]=="18:30 (Sunset)", "Time"]="18:30"
data.loc[data["Time"]=="06j00", "Time"]="06:00"
data.loc[data["Time"]=="Prior to 10:37", "Time"]="10:00"
data.loc[data["Time"]=="Daybreak", "Time"]="20:00"
data.loc[data["Time"]==">12:00", "Time"]="12:00"
data.loc[data["Time"]=="Mid-morning", "Time"]="11:00"
data.loc[data["Time"]=="16:30 or 18:00", "Time"]="18:00"
data.loc[data["Time"]=="Just before dawn", "Time"]="19:00"
data.loc[data["Time"]=="Daytime", "Time"]="10:00"
data.loc[data["Time"]=="Dark", "Time"]="23:00"
data.loc[data["Time"]=="10:00 / 11:00", "Time"]="10:00"
data.loc[data["Time"]=='"After lunc:"', "Time"]="16:00"
data.loc[data["Time"]=='15:00 or 15:45', "Time"]="15:00"
data.loc[data["Time"]=='>17:00', "Time"]="17:00"
data.loc[data["Time"]=='19:00 / 20:00', "Time"]="19:00"
data.loc[data["Time"]=="12:45 / 13:45", "Time"]="13:00"
data.loc[data["Time"]=="14:00 - 15:00", "Time"]="14:00"
data.loc[data["Time"]=="nig:t", "Time"]="20:00"
data.loc[data["Time"]=="03:45 - 04:00", "Time"]="03:00"
data.loc[data["Time"]=="Late nig:t", "Time"]="23:00"
data.loc[data["Time"]=="10:30 or 13:30", "Time"]="12:00"
data.loc[data["Time"]=="15:00j", "Time"]="15:00"
data.loc[data["Time"]=="Midday.", "Time"]="12:00"
data.loc[data["Time"]=='"After dark"', "Time"]="23:00"
data.loc[data["Time"]=='10:00 or 14:00"', "Time"]="23:00"
data.loc[data["Time"]=="2 :rs before sunset", "Time"]="16:00"
data.loc[data["Time"]=="18:15 to 21:30", "Time"]="16:00"
data.loc[data["Time"]=="1500", "Time"]="15:00"
data.loc[data["Time"]=="A.M.", "Time"]="09:00"

# %%
def time_of_day(hour): # funcion para agrupar y asi reducir la cantidad de horas del dia en periodos preestablecidos

    if '07' in hour or '08' in hour or '09' in hour or '10' in hour or '11' in hour or '12' in hour:
        return 'Morning'
    elif '13' in hour or '14' in hour or '15' in hour or '16' in hour or '17' in hour or '18' in hour or '19' in hour or '20' in hour or '21' in hour:
        return 'Afternoon'
    elif '22' in hour or '23' in hour or '00' in hour or '01' in hour or '02' in hour or '03' in hour or '04' in hour or '05' in hour or '06' in hour:
        return 'Night'
    else:
        return 'No information'
data["Time_groups"] = data['Time'].apply(time_of_day)

# %%
data["Time_groups"].unique()
# Out:
# array(['Afternoon', 'Morning', 'No information', 'Night'], dtype=object)

# %%
data["Time"].unique()
# Out:
# array(['18:00', '14:30', '07:45', 'unknown', '17:00', '14:00', '9:00',
#        '15:00', '08:15', '11:00', '10:30', '10:40', '16:50', '07:00',
#        '09:30', '08:00', '17:35', '15:30', '07:30', '19:00', '21:00',
#        '16:00', '15:01', '12:00', '13:45', '23:30', '09:00', '18:30',
#        '12:30', '16:30', '18:45', '06:00', '10:00', '10:44', '13:19',
#        '13:00', '13:30', '10:45', '11:20', '11:45', '19:30', '08:30',
#        '15:45', '11:30', '17:34', '17:10', '11:15', '08:50', '17:45',
#        '10:20', '13:20', '02:00', '09:50', '17:30', '10:43', '15:15',
#        '15:40', '19:05', '1300', '22:00', '16:20', '14:34', '15:25',
#        '14:55', '17:46', '15:49', '24:00', '09:40', '10:15', '18:15',
#        '04:00', '14:50', '13:50', '19:20', '10:25', '16:45', '15:52',
#        '06:15', '14:40', '19:45', '10:10', '08:45', '20:00', '12:10',
#        '18:05', '11:41', '12:25', '17:51', '16:12', '12:45', '10:50',
# ...

# %%
#data['age'] = pd.to_numeric(data['age'], errors='coerce').fillna(0).astype(int)

"""if age <= '12':

            return 'kid'

        elif age <= '19':

            return 'teen'

        elif age <= '60':

            return 'adult'

        elif age >= '60':

            return 'elderly'

        else:
            return 'No information'

data['age'] = data['age'].apply(age_of_victims)""" #falta ponerle 0 primero
