# %%
import pandas as pd
import numpy as np
from repo_funciones import *

# %%
pd.set_option('display.max_columns', None)

# %%
data = pd.read_csv('../Sharknado/attacks_messy.csv', encoding='utf-8',encoding_errors="ignore" )

# %%
dim_original = data.shape #Para luego ir comparando
dim_original
# Out:
# (25723, 24)

# %%
data.head() #con tail() vemos que al final hay muchos valores nulos
# Out:
#   Case Number         Date    Year        Type    Country             Area
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California  \
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity            Name Sex   Age
# 0     Oceanside, San Diego County     Paddling     Julie Wolfe    F   57  \
# 1  St. Simon Island, Glynn County     Standing  AdysonMcNeely     F   11
# 2                    Habush, Oahu      Surfing     John Denges    M   48
# 3              Arrawarra Headland      Surfing            male    M  NaN
# 4                        La Ticla  Free diving  Gustavo Ramos     M  NaN
#
#                                               Injury Fatal (Y/N)
# ...

# %%
data.info() #guay pero falta ver donnde hay mas trabajo. Un conteo de valores nulos por column o algo asi
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
# ...

# %%
data["Unnamed: 22"].unique()
# Out:
# array([nan, 'stopped here'], dtype=object)

# %%
data["Unnamed: 23"].unique()
# Out:
# array([nan, 'Teramo', 'change filename'], dtype=object)

# %%
#columnas 22 y 23 tienen demasiados valores nulos para ser representatrivas. las rellenamos
data[["Unnamed: 23", "Unnamed: 22"]] = data[["Unnamed: 23", "Unnamed: 22"]].fillna(0)

# %%
data["Time"].unique()
# Out:
# array(['18h00', '14h00  -15h00', '07h45', nan, 'Late afternoon', '17h00',
#        '14h00', 'Morning', '15h00', '08h15', '11h00', '10h30', '10h40',
#        '16h50', '07h00', '09h30', 'Afternoon', '21h50', '09h40', '08h00',
#        '17h35', '15h30', '07h30', '19h00, Dusk', 'Night', '16h00',
#        '15h01', '12h00', '13h45', '23h30', '09h00', '14h30', '18h30',
#        '12h30', '16h30', '18h45', '06h00', '10h00', '10h44', '13h19',
#        'Midday', '13h30', '10h45', '11h20', '11h45', '19h30', '08h30',
#        '15h45', 'Shortly before 12h00', '17h34', '17h10', '11h15',
#        '08h50', '17h45', '13h00', '10h20', '13h20', '02h00', '09h50',
#        '11h30', '17h30', '9h00', '10h43', 'After noon', '15h15', '15h40',
#        '19h05', '1300', '14h30 / 15h30', '22h00', '16h20', '14h34',
#        '15h25', '14h55', '17h46', 'Morning ', '15h49', '19h00',
#        'Midnight', '09h30 / 10h00', '10h15', '18h15', '04h00', '14h50',
# ...

# %%
data["Time"]=data["Time"].fillna("unknown")

# %%
data.loc[12861]
# Out:
# Case Number                   NaN
# Date                          NaN
# Year                          NaN
# Type                          NaN
# Country                       NaN
# Area                          NaN
# Location                      NaN
# Activity                      NaN
# Name                          NaN
# Sex                           NaN
# Age                           NaN
# Injury                        NaN
# Fatal (Y/N)                   NaN
# Time                      unknown
# Species                       NaN
# Investigator or Source        NaN
# pdf                           NaN
# href formula                  NaN
# href                          NaN
# Case Number.1                 NaN
# Case Number.2                 NaN
# original order                NaN
# Unnamed: 22                     0
# Unnamed: 23                     0
# Name: 12861, dtype: object

# %%
data.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 25718     True
# 25719     True
# 25720     True
# 25721     True
# 25722    False
# Length: 25723, dtype: bool

# %%
duplicated_data = data[data.duplicated()]
duplicated_data
# Out:
#       Case Number Date  Year Type Country Area Location Activity Name Sex
# 6310            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN  \
# 6311            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6312            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6313            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6314            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# ...           ...  ...   ...  ...     ...  ...      ...      ...  ...  ...
# 25717         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25718         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25719         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25720         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25721         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
#
# ...

# %%
data= data.drop_duplicates()

# %%
data.shape, dim_original
# Out:
# ((6312, 24), (25723, 24))

# %%
data=data.drop(nan_rows[nan_rows > 19])

# %%
data.shape, dim_original
# Out:
# ((6310, 24), (25723, 24))

# %%
data.tail()
# Out:
#       Case Number Date  Year Type Country Area Location Activity Name Sex
# 6307            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN  \
# 6308            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6309            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8702          NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25722          xx  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
#
#        Age Injury Fatal (Y/N)     Time Species  Investigator or Source  pdf
# 6307   NaN    NaN         NaN  unknown      NaN                    NaN  NaN  \
# 6308   NaN    NaN         NaN  unknown      NaN                    NaN  NaN
# 6309   NaN    NaN         NaN  unknown      NaN                    NaN  NaN
# 8702   NaN    NaN         NaN  unknown      NaN                    NaN  NaN
# 25722  NaN    NaN         NaN  unknown      NaN                    NaN  NaN
#
# ...

# %%
data = data.drop([6307, 6308, 6309, 8702, 25722])

# %%
data= data.drop(data["Case Number"][data["Case Number"]==0])

# %%
data.shape, dim_original
# Out:
# ((6305, 24), (25723, 24))

# %%
data = data.drop(data[nanrows(data) >= 15].index)
# Out:
# C:\Users\anton\AppData\Local\Temp\ipykernel_11108\955605597.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data = data.drop(data[nanrows(data) >= 15].index)

# %%
data.shape, dim_original
# Out:
# ((6300, 24), (25723, 24))

# %%
data["Case Number"][data["Case Number"].isna()]
# Out:
# 5488    NaN
# Name: Case Number, dtype: object

# %%
data.loc[data["Case Number"].isna()]
# Out:
#      Case Number                  Date    Year      Type Country     Area
# 5488         NaN  Reported 06-Sep-1905  1905.0  Provoked     USA  Florida  \
#
#                           Location Activity         Name Sex   Age
# 5488  Fort Pierce, St Lucie County  Fishing  David Curry    M  NaN  \
#
#                                                  Injury Fatal (Y/N)     Time
# 5488  Lacerations to leg from hooked shark PROVOKED ...           N  unknown  \
#
#      Species           Investigator or Source                     pdf
# 5488      NaN  Muncie Evening Press, 8/6/1913  1905.09.06.R-Curry.pdf  \
#
#                                            href formula
# 5488  http://sharkattackfile.net/spreadsheets/pdf_di...  \
#
#                                                    href Case Number.1
# 5488  http://sharkattackfile.net/spreadsheets/pdf_di...  1905.09.06.R  \
#
#      Case Number.2  original order Unnamed: 22 Unnamed: 23
# ...

# %%
data["Case Number"].fillna("1905.09.06.R", inplace=True)

# %%
data.loc[data["Year"].isna()]
# Out:
#        Case Number                  Date  Year        Type    Country
# 187   2017.01.08.R  Reported 08-Jan-2017   NaN     Invalid  AUSTRALIA  \
# 6079  1836.08.19.R  Reported 19-Aug-1836   NaN  Unprovoked    ENGLAND
#
#             Area    Location      Activity          Name Sex   Age
# 187   Queensland         NaN  Spearfishing  Kerry Daniel    M   35  \
# 6079  Cumberland  Whitehaven      Swimming         a boy    M  NaN
#
#                                       Injury Fatal (Y/N)     Time    Species
# 187   No attack, shark made a threat display         NaN  unknown  Bull shark  \
# 6079                                   FATAL           Y  unknown         NaN
#
#       Investigator or Source                           pdf
# 187   Liquid Vision 1/8/2017  2017.01.08.R-KerryDaniel.pdf  \
# 6079          C. Moore, GSAF   1835.08.19.R-Whitehaven.pdf
#
#                                            href formula
# 187   http://sharkattackfile.net/spreadsheets/pdf_di...  \
# ...

# %%
#data["Year"].fillna(data["Case Number"], inplace=True) #elc ase number viene elk año, luego habrá que limpiarlo...

# %%
data["Sex "].fillna("unknown", inplace=True) #no hay indicios de sexo para estos valores nulos.

# %%
data["Type"].fillna("Invalid", inplace=True)

# %%
data["href formula"].fillna(data["href"], inplace=True)

# %%
data.loc[data["Investigator or Source"].isna()].head()
# Out:
#        Case Number         Date    Year        Type    Country
# 119   2017.07.14.a  14-Jul-2017  2017.0  Unprovoked  AUSTRALIA  \
# 290   2016.04.07.b  07-Apr-2016  2016.0  Unprovoked        USA
# 382     2015.07.27  27-Jul-2015  2015.0     Invalid  AUSTRALIA
# 631   2013.08.31.b  31-Aug-2013  2013.0  Unprovoked    BAHAMAS
# 1130    2009.04.28  28-Apr-2009  2009.0  Unprovoked        USA
#
#                    Area                          Location      Activity
# 119   Western Australia                     Floreat Beach       Surfing  \
# 290             Florida       Florida Keys, Monroe County       Fishing
# 382            Victoria                  Tyrendarra Beach       Surfing
# 631                 NaN                    Freetown Beach  Spearfishing
# 1130            Florida  St. Augustine, St. John's County           NaN
#
#                  Name Sex   Age                                      Injury
# ...

# %%
data.tail()
# Out:
#      Case Number         Date  Year        Type             Country
# 6297     ND.0005  Before 1903   0.0  Unprovoked           AUSTRALIA  \
# 6298     ND.0004  Before 1903   0.0  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905   0.0  Unprovoked                 USA
# 6300     ND.0002    1883-1889   0.0  Unprovoked              PANAMA
# 6301     ND.0001    1845-1853   0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity
# 6297  Western Australia                          Roebuck Bay        Diving  \
# 6298  Western Australia                                  NaN  Pearl diving
# 6299     North Carolina                       Ocracoke Inlet      Swimming
# 6300                NaN                   Panama Bay 8N, 79W           NaN
# 6301   Eastern Province  Below the English fort, Trincomalee      Swimming
#
#                        Name Sex   Age
# 6297                   male    M  NaN  \
# ...

# %%
data["Name"].fillna("NA" , inplace=True) #La variable nombre en verdad no creo sea indicativa de nada para analisis. Será que las lucias son mas propensas a ataques? pos wel never know

# %%
data.loc[data[['Country', 'Area', 'Location']].isna().all(axis=1), ['Country', 'Area', 'Location']] = "unknown" #si las tres columnas no tienen valor a la vez, remplazar con unknown. Para las que al menos una de ellas tengan valores podemos hacer algo maybe

# %%
def unique_cols(x):
    unique_cols = x.nunique()
    return unique_cols.sort_values(ascending=False)

# %%
unique_cols(data) #algunos no tiene sentido que tengan tantos valores unicos, como sexo, fatal...
# Out:
# original order            6299
# pdf                       6289
# href formula              6289
# Case Number               6284
# Case Number.2             6284
# Case Number.1             6283
# href                      6283
# Date                      5432
# Name                      5229
# Investigator or Source    4969
# Location                  4101
# Injury                    3737
# Species                   1547
# Activity                  1532
# Area                       826
# Time                       366
# Year                       249
# Country                    213
# Age                        155
# Fatal (Y/N)                  8
# Type                         8
# Sex                          7
# Unnamed: 23                  3
# Unnamed: 22                  2
# dtype: int64

# %%
data["Sex "].unique()
# Out:
# array(['F', 'M', 'unknown', 'M ', 'lli', 'N', '.'], dtype=object)

# %%
data[data['Sex '] == "."]="unknown" #para tener un . mejor un unknwown, son varias personas enb injury decen asi que unknown

# %%
print(data.loc[5435, 'Injury'])
# Out:
# FATAL

# %%
data[data['Sex '] == 'lli']="M" #tiene nombre de hombre

# %%
data[data['Sex '] == 'N']= "M" #nombres de hombres

# %%
data[data['Sex '] == 'M ']= "M"

# %%
data["Fatal (Y/N)"].unique()
# Out:
# array(['N', 'Y', nan, 'M', 'UNKNOWN', '2017', ' N', 'N ', 'unknown', 'y'],
#       dtype=object)

# %%
data[data["Fatal (Y/N)"] == 'M'] #vemos que hay columnas con todo valores M en 561,1585,4936,6129
# Out:
#        Case Number         Date    Year      Type           Country      Area
# 285   2016.04.18.b  18-Apr-2016  2016.0  Provoked  FRENCH POLYNESIA  Tuamotos  \
# 563              M            M       M         M                 M         M
# 1587             M            M       M         M                 M         M
# 1624             M            M       M         M                 M         M
# 4938             M            M       M         M                 M         M
# 6131             M            M       M         M                 M         M
#
#           Location      Activity         Name Sex  Age
# 285   Makemo Atoll  Spearfishing  Hoata Iotua    M  22  \
# 563              M             M            M    M   M
# 1587             M             M            M    M   M
# 1624             M             M            M    M   M
# 4938             M             M            M    M   M
# 6131             M             M            M    M   M
#
# ...

# %%
data = data.reset_index(drop=True)

# %%
data = data.drop([561,1585,4936,6129,1622])

# %%
data[data["Fatal (Y/N)"] == 'M']="N" #injury no parece indicar que murió, ponemos no

# %%
print(data.loc[283, 'Injury'])
# Out:
# N

# %%
data[data["Fatal (Y/N)"] == '2017']="N"

# %%
data[data["Fatal (Y/N)"] == 'y']="Y"

# %%
data[data["Fatal (Y/N)"] == 'N ']="N"

# %%
data[data["Fatal (Y/N)"] == ' N']="N"

# %%
data[data["Fatal (Y/N)"]=="UNKNOWN"]="unknown"

# %%
data.loc[(data["Fatal (Y/N)"].isna()) & (data["Injury"] == "FATAL"), "Fatal (Y/N)"] = "Y"

# %%
data.loc[data["Fatal (Y/N)"].isna()]="unknown"

# %%
data.loc[data["Year"].isna()]
# Out:
#        Case Number                  Date Year        Type  Country
# 6077  1836.08.19.R  Reported 19-Aug-1836  NaN  Unprovoked  ENGLAND  \
#
#             Area    Location  Activity   Name Sex   Age Injury Fatal (Y/N)
# 6077  Cumberland  Whitehaven  Swimming  a boy    M  NaN  FATAL           Y  \
#
#          Time Species  Investigator or Source                          pdf
# 6077  unknown      NaN         C. Moore, GSAF  1835.08.19.R-Whitehaven.pdf  \
#
#                                            href formula
# 6077  http://sharkattackfile.net/spreadsheets/pdf_di...  \
#
#                                                    href Case Number.1
# 6077  http://sharkattackfile.net/spreadsheets/pdf_di...  1836.08.19.R  \
#
#      Case Number.2 original order Unnamed: 22 Unnamed: 23
# 6077  1836.08.19.R          224.0           0           0

# %%
data.loc[6077, "Year"] = 2017

# %%
def get_unique_dtypes(df, col):
    unique_dtypes = df[col].apply(lambda x: type(x)).unique()
    return unique_dtypes

# %%
get_unique_dtypes(data, "Year")
# Out:
# array([<class 'float'>, <class 'str'>, <class 'int'>], dtype=object)

# %%
data.loc[data["Year"]=="NaN"]
# Out:
# Empty DataFrame
# Columns: [Case Number, Date, Year, Type, Country, Area, Location, Activity, Name, Sex , Age, Injury, Fatal (Y/N), Time, Species , Investigator or Source, pdf, href formula, href, Case Number.1, Case Number.2, original order, Unnamed: 22, Unnamed: 23]
# Index: []
